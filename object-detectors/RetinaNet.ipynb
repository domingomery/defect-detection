# %% [markdown]
# # Defect detection in aluminum castings using RetinaNet
#
# Example using series C0001 of [GDXray](https://domingomery.ing.puc.cl/material/gdxray/). Training and validation using simulated ellipsoidal defects only. Testing on real defects only. Training, Validation and Testing images belong to the same type of wheel. The idea is to demonstrate that we can inspect a type of wheel if we train using the images of this wheel with no defects + simulated defects and test the model on X-ray images of the same type of wheel with real defects.
#
# This example is based on RetinaNet Tutorial from original GitHub (https://github.com/fizyr/keras-retinanet) in Keras.

# %% [markdown]
# # Environment Setup
# Download and install in Colab required packages and import libraries.

# %%
# stable versions for keras-retinanet
# !pip3 install keras==2.3.1
# !pip3 install tensorflow==1.15

# download keras-retinanet
# !git clone https://github.com/fizyr/keras-retinanet.git
# %cd keras-retinanet/
# !pip install .
# !python setup.py build_ext --inplace
import torch
from IPython.display import Image, clear_output  # to display images
import os
import shutil
import zipfile
import urllib
import xml.etree.ElementTree as ET
import numpy as np
import csv
import pandas
from google.colab import drive
from google.colab import files
clear_output()
print('Setup done')
# Out:
# Setup done

# %% [markdown]
# # Download casting data
#
# Training, validation and testing images and annotations of series C0001 of GDXray.

# %%
# download training images and annotations
# !wget https://www.dropbox.com/s/hjfbghm53oe7uw9/cast.zip
# !unzip cast.zip
# !rm cast.zip
# !mv cast/images cast/csv
clear_output()
print('cast.zip unzipped and copied')
# Out:
# cast.zip unzipped and copied

# %% [markdown]
# # Setup training parameters

# %%
PRETRAINED_MODEL = './snapshots/_pretrained_model.h5'
URL_MODEL        = 'https://github.com/fizyr/keras-retinanet/releases/download/0.5.1/resnet50_coco_best_v2.1.0.h5'
urllib.request.urlretrieve(URL_MODEL, PRETRAINED_MODEL)
print('Downloaded pretrained model to ' + PRETRAINED_MODEL)
# Out:
# Downloaded pretrained model to ./snapshots/_pretrained_model.h5

# %%
ynew  = 1 # 1 for new training using YOLOv3 pretrained weights, 0 for last weights computed after training
# first run must be with ynew = 1, second run could be with ynew = 0 using last weights (to continue the training with additional epochs)


CSV_TRAIN     = 'cast/csv/annotations_train.csv cast/csv/classes.csv'
CSV_TEST      = 'cast/csv/annotations_test.csv  cast/csv/classes.csv'
CSV_VAL       = 'cast/csv/annotations_val.csv'
CSV_VALS      = 'cast/csv/annotations_val.csv  cast/csv/classes.csv'
CLASSES       = 'cast/csv/classes.csv'
EPOCHS        = 50
# Select initial weights for training
if ynew == 1:
  TRAIN_WEIGHTS = PRETRAINED_MODEL
else:
  TRAIN_WEIGHTS = './snapshots/resnet50_csv_xx.h5' #<--- see corresponding number xx

# %% [markdown]
# # Training
#
# RetinaNet model will be trained according setup of last cell using {TRAIN_WEIGHTS}

# %%
# !python keras_retinanet/bin/train.py --freeze-backbone --random-transform --weights {TRAIN_WEIGHTS} --batch-size 16 --steps 200 --epochs {EPOCHS} csv {CSV_TRAIN} --val-annotations {CSV_VAL}
# Out:
# Using TensorFlow backend.
# Creating model, this may take a second...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1319: UserWarning: Skipping loading of weights for layer classification_submodel due to mismatch in shape ((3, 3, 256, 9) vs (720, 256, 3, 3)).
#   weight_values[i].shape))
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:1319: UserWarning: Skipping loading of weights for layer classification_submodel due to mismatch in shape ((9,) vs (720,)).
#   weight_values[i].shape))
# 2020-08-10 20:44:03.182559: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-10 20:44:03.226502: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 20:44:03.227123: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-08-10 20:44:03.242625: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 20:44:03.432832: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-10 20:44:03.528032: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-10 20:44:03.553576: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-10 20:44:03.812511: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-10 20:44:03.938300: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-10 20:44:04.457103: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 20:44:04.457352: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 20:44:04.458207: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 20:44:04.458771: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-10 20:44:04.459180: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-08-10 20:44:04.464582: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-08-10 20:44:04.464883: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xe3584c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-10 20:44:04.464918: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-10 20:44:04.579432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 20:44:04.580179: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xe358680 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-08-10 20:44:04.580208: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-08-10 20:44:04.581353: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 20:44:04.581995: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-08-10 20:44:04.582055: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 20:44:04.582071: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-10 20:44:04.582084: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-10 20:44:04.582097: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-10 20:44:04.582115: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-10 20:44:04.582129: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-10 20:44:04.582144: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 20:44:04.582249: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 20:44:04.582843: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 20:44:04.583337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-10 20:44:04.583393: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 20:44:04.584493: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-10 20:44:04.584519: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-08-10 20:44:04.584526: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-08-10 20:44:04.584643: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 20:44:04.585408: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 20:44:04.585893: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-08-10 20:44:04.585925: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_1:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_2:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_3:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_4:0' shape=(9, 4) dtype=float32> anchors
# WARNING:tensorflow:From keras_retinanet/bin/../../keras_retinanet/backend/tensorflow_backend.py:104: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "retinanet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# padding_conv1 (ZeroPadding2D)   (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9408        padding_conv1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, None, None, 6 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4096        pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_relu (Activation (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2a_branch2b (ZeroPadding (None, None, None, 6 0           res2a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36864       padding2a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_relu (Activation (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16384       res2a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16384       pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a_relu (Activation)         (None, None, None, 2 0           res2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16384       res2a_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a_relu (Activation (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2b_branch2b (ZeroPadding (None, None, None, 6 0           res2b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36864       padding2b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_relu (Activation (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16384       res2b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# res2b (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  res2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_relu (Activation)         (None, None, None, 2 0           res2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16384       res2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a_relu (Activation (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2c_branch2b (ZeroPadding (None, None, None, 6 0           res2c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36864       padding2c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_relu (Activation (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16384       res2c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# res2c (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  res2b_relu[0][0]
# __________________________________________________________________________________________________
# res2c_relu (Activation)         (None, None, None, 2 0           res2c[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32768       res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_relu (Activation (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3a_branch2b (ZeroPadding (None, None, None, 1 0           res3a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147456      padding3a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_relu (Activation (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 65536       res3a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131072      res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a_relu (Activation)         (None, None, None, 5 0           res3a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65536       res3a_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a_relu (Activation (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3b_branch2b (ZeroPadding (None, None, None, 1 0           res3b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147456      padding3b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b_relu (Activation (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 65536       res3b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  res3a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_relu (Activation)         (None, None, None, 5 0           res3b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65536       res3b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a_relu (Activation (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3c_branch2b (ZeroPadding (None, None, None, 1 0           res3c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147456      padding3c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b_relu (Activation (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 65536       res3c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# res3c (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  res3b_relu[0][0]
# __________________________________________________________________________________________________
# res3c_relu (Activation)         (None, None, None, 5 0           res3c[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65536       res3c_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a_relu (Activation (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3d_branch2b (ZeroPadding (None, None, None, 1 0           res3d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147456      padding3d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b_relu (Activation (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 65536       res3d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# res3d (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  res3c_relu[0][0]
# __________________________________________________________________________________________________
# res3d_relu (Activation)         (None, None, None, 5 0           res3d[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131072      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_relu (Activation (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4a_branch2b (ZeroPadding (None, None, None, 2 0           res4a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 589824      padding4a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_relu (Activation (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 262144      res4a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 524288      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a_relu (Activation)         (None, None, None, 1 0           res4a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262144      res4a_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a_relu (Activation (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4b_branch2b (ZeroPadding (None, None, None, 2 0           res4b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 589824      padding4b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b_relu (Activation (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 262144      res4b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# res4b (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  res4a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_relu (Activation)         (None, None, None, 1 0           res4b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262144      res4b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a_relu (Activation (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4c_branch2b (ZeroPadding (None, None, None, 2 0           res4c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 589824      padding4c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b_relu (Activation (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 262144      res4c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# res4c (Add)                     (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  res4b_relu[0][0]
# __________________________________________________________________________________________________
# res4c_relu (Activation)         (None, None, None, 1 0           res4c[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262144      res4c_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a_relu (Activation (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4d_branch2b (ZeroPadding (None, None, None, 2 0           res4d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 589824      padding4d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b_relu (Activation (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 262144      res4d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# res4d (Add)                     (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  res4c_relu[0][0]
# __________________________________________________________________________________________________
# res4d_relu (Activation)         (None, None, None, 1 0           res4d[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262144      res4d_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a_relu (Activation (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4e_branch2b (ZeroPadding (None, None, None, 2 0           res4e_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 589824      padding4e_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b_relu (Activation (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 262144      res4e_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# res4e (Add)                     (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  res4d_relu[0][0]
# __________________________________________________________________________________________________
# res4e_relu (Activation)         (None, None, None, 1 0           res4e[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262144      res4e_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a_relu (Activation (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4f_branch2b (ZeroPadding (None, None, None, 2 0           res4f_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 589824      padding4f_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b_relu (Activation (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 262144      res4f_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# res4f (Add)                     (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  res4e_relu[0][0]
# __________________________________________________________________________________________________
# res4f_relu (Activation)         (None, None, None, 1 0           res4f[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524288      res4f_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a_relu (Activation (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5a_branch2b (ZeroPadding (None, None, None, 5 0           res5a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b_relu (Activation (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1048576     res5a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2097152     res4f_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a (Add)                     (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a_relu (Activation)         (None, None, None, 2 0           res5a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1048576     res5a_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a_relu (Activation (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5b_branch2b (ZeroPadding (None, None, None, 5 0           res5b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b_relu (Activation (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1048576     res5b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# res5b (Add)                     (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  res5a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_relu (Activation)         (None, None, None, 2 0           res5b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1048576     res5b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a_relu (Activation (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5c_branch2b (ZeroPadding (None, None, None, 5 0           res5c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b_relu (Activation (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1048576     res5c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# res5c (Add)                     (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  res5b_relu[0][0]
# __________________________________________________________________________________________________
# res5c_relu (Activation)         (None, None, None, 2 0           res5c[0][0]
# __________________________________________________________________________________________________
# C5_reduced (Conv2D)             (None, None, None, 2 524544      res5c_relu[0][0]
# __________________________________________________________________________________________________
# P5_upsampled (UpsampleLike)     (None, None, None, 2 0           C5_reduced[0][0]
#                                                                  res4f_relu[0][0]
# __________________________________________________________________________________________________
# C4_reduced (Conv2D)             (None, None, None, 2 262400      res4f_relu[0][0]
# __________________________________________________________________________________________________
# P4_merged (Add)                 (None, None, None, 2 0           P5_upsampled[0][0]
#                                                                  C4_reduced[0][0]
# __________________________________________________________________________________________________
# P4_upsampled (UpsampleLike)     (None, None, None, 2 0           P4_merged[0][0]
#                                                                  res3d_relu[0][0]
# __________________________________________________________________________________________________
# C3_reduced (Conv2D)             (None, None, None, 2 131328      res3d_relu[0][0]
# __________________________________________________________________________________________________
# P6 (Conv2D)                     (None, None, None, 2 4718848     res5c_relu[0][0]
# __________________________________________________________________________________________________
# P3_merged (Add)                 (None, None, None, 2 0           P4_upsampled[0][0]
#                                                                  C3_reduced[0][0]
# __________________________________________________________________________________________________
# C6_relu (Activation)            (None, None, None, 2 0           P6[0][0]
# __________________________________________________________________________________________________
# P3 (Conv2D)                     (None, None, None, 2 590080      P3_merged[0][0]
# __________________________________________________________________________________________________
# P4 (Conv2D)                     (None, None, None, 2 590080      P4_merged[0][0]
# __________________________________________________________________________________________________
# P5 (Conv2D)                     (None, None, None, 2 590080      C5_reduced[0][0]
# __________________________________________________________________________________________________
# P7 (Conv2D)                     (None, None, None, 2 590080      C6_relu[0][0]
# __________________________________________________________________________________________________
# regression_submodel (Model)     (None, None, 4)      2443300     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# classification_submodel (Model) (None, None, 1)      2381065     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# regression (Concatenate)        (None, None, 4)      0           regression_submodel[1][0]
#                                                                  regression_submodel[2][0]
#                                                                  regression_submodel[3][0]
#                                                                  regression_submodel[4][0]
#                                                                  regression_submodel[5][0]
# __________________________________________________________________________________________________
# classification (Concatenate)    (None, None, 1)      0           classification_submodel[1][0]
#                                                                  classification_submodel[2][0]
#                                                                  classification_submodel[3][0]
#                                                                  classification_submodel[4][0]
#                                                                  classification_submodel[5][0]
# ==================================================================================================
# Total params: 36,382,957
# Trainable params: 12,821,805
# Non-trainable params: 23,561,152
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/50
# 2020-08-10 20:44:13.106398: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 20:44:17.659404: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 200/200 [==============================] - 326s 2s/step - loss: 2.9855 - regression_loss: 2.2603 - classification_loss: 0.7251
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:02:00 Time:  0:02:00
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.5054
# mAP: 0.5054
#
# Epoch 00001: saving model to ./snapshots/resnet50_csv_01.h5
# Epoch 2/50
# 200/200 [==============================] - 304s 2s/step - loss: 1.7334 - regression_loss: 1.4424 - classification_loss: 0.2911
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:50 Time:  0:01:50
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.8064
# mAP: 0.8064
#
# Epoch 00002: saving model to ./snapshots/resnet50_csv_02.h5
# Epoch 3/50
# 200/200 [==============================] - 313s 2s/step - loss: 1.4641 - regression_loss: 1.2258 - classification_loss: 0.2383
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:49 Time:  0:01:49
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.8703
# mAP: 0.8703
#
# Epoch 00003: saving model to ./snapshots/resnet50_csv_03.h5
# Epoch 4/50
# 200/200 [==============================] - 310s 2s/step - loss: 1.3348 - regression_loss: 1.1234 - classification_loss: 0.2114
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:46 Time:  0:01:46
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.8981
# mAP: 0.8981
#
# Epoch 00004: saving model to ./snapshots/resnet50_csv_04.h5
# Epoch 5/50
# 200/200 [==============================] - 316s 2s/step - loss: 1.2503 - regression_loss: 1.0582 - classification_loss: 0.1921
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:47 Time:  0:01:47
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.9163
# mAP: 0.9163
#
# Epoch 00005: saving model to ./snapshots/resnet50_csv_05.h5
# Epoch 6/50
# 200/200 [==============================] - 302s 2s/step - loss: 1.1815 - regression_loss: 1.0068 - classification_loss: 0.1747
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:46 Time:  0:01:46
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.9235
# mAP: 0.9235
#
# Epoch 00006: saving model to ./snapshots/resnet50_csv_06.h5
# Epoch 7/50
# 200/200 [==============================] - 304s 2s/step - loss: 1.1437 - regression_loss: 0.9802 - classification_loss: 0.1635
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:45 Time:  0:01:45
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.9340
# mAP: 0.9340
#
# Epoch 00007: saving model to ./snapshots/resnet50_csv_07.h5
# Epoch 8/50
# 200/200 [==============================] - 307s 2s/step - loss: 1.1058 - regression_loss: 0.9522 - classification_loss: 0.1535
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:45 Time:  0:01:45
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.9367
# mAP: 0.9367
#
# Epoch 00008: saving model to ./snapshots/resnet50_csv_08.h5
# Epoch 9/50
# 200/200 [==============================] - 310s 2s/step - loss: 1.0749 - regression_loss: 0.9299 - classification_loss: 0.1450
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:46 Time:  0:01:46
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.9412
# mAP: 0.9412
#
# Epoch 00009: saving model to ./snapshots/resnet50_csv_09.h5
# Epoch 10/50
# 200/200 [==============================] - 310s 2s/step - loss: 1.0529 - regression_loss: 0.9134 - classification_loss: 0.1394
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:45 Time:  0:01:45
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.9472
# mAP: 0.9472
#
# Epoch 00010: saving model to ./snapshots/resnet50_csv_10.h5
# Epoch 11/50
# 200/200 [==============================] - 307s 2s/step - loss: 1.0294 - regression_loss: 0.8962 - classification_loss: 0.1333
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:45 Time:  0:01:45
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.9500
# mAP: 0.9500
#
# Epoch 00011: saving model to ./snapshots/resnet50_csv_11.h5
# Epoch 12/50
# 200/200 [==============================] - 314s 2s/step - loss: 1.0140 - regression_loss: 0.8850 - classification_loss: 0.1290
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:45 Time:  0:01:45
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.9464
# mAP: 0.9464
#
# Epoch 00012: saving model to ./snapshots/resnet50_csv_12.h5
# Epoch 13/50
# 200/200 [==============================] - 311s 2s/step - loss: 1.0001 - regression_loss: 0.8754 - classification_loss: 0.1247
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:45 Time:  0:01:45
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.9523
# mAP: 0.9523
#
# Epoch 00013: saving model to ./snapshots/resnet50_csv_13.h5
# Epoch 14/50
# 200/200 [==============================] - 300s 1s/step - loss: 0.9777 - regression_loss: 0.8574 - classification_loss: 0.1203
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:45 Time:  0:01:45
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.9543
# mAP: 0.9543
#
# Epoch 00014: saving model to ./snapshots/resnet50_csv_14.h5
# Epoch 15/50
# 200/200 [==============================] - 302s 2s/step - loss: 0.9661 - regression_loss: 0.8487 - classification_loss: 0.1174
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:01:45 Time:  0:01:45
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.9562
# mAP: 0.9562
#
# Epoch 00015: saving model to ./snapshots/resnet50_csv_15.h5

# %%
# Conversion of train model into a inference model (this is necessary to mAP computation)
TRAINED_MODEL = './snapshots/resnet50_csv_15.h5' # <--- include here last trained model xx should be the number of EPOCHS
INFERENCE_MODEL = 'newmodel.h5'
# !keras_retinanet/bin/convert_model.py {TRAINED_MODEL} {INFERENCE_MODEL}
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 2020-08-10 22:45:11.408735: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-10 22:45:11.411323: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-08-10 22:45:11.411372: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: 63394f44872e
# 2020-08-10 22:45:11.411391: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: 63394f44872e
# 2020-08-10 22:45:11.411478: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 418.67.0
# 2020-08-10 22:45:11.411511: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 418.67.0
# 2020-08-10 22:45:11.411524: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 418.67.0
# 2020-08-10 22:45:11.411798: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-08-10 22:45:11.416275: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-08-10 22:45:11.416537: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xe76b500 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-10 22:45:11.416571: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From keras_retinanet/bin/../../keras_retinanet/backend/tensorflow_backend.py:104: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_1:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_2:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_3:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_4:0' shape=(9, 4) dtype=float32> anchors

# %% [markdown]
# # Evaluation of Performance

# %%
# Computation of mAP on testing subset
# !keras_retinanet/bin/evaluate.py --save-path output_map_test --iou-threshold 0.5 --score-threshold 0.05 csv {CSV_TEST} {INFERENCE_MODEL}
# Out:
# Using TensorFlow backend.
# Loading model, this may take a second...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_1:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_2:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_3:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_4:0' shape=(9, 4) dtype=float32> anchors
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From keras_retinanet/bin/../../keras_retinanet/backend/tensorflow_backend.py:104: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2020-08-10 22:45:43.672554: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-10 22:45:43.694714: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:45:43.695327: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-08-10 22:45:43.695664: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 22:45:43.697556: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-10 22:45:43.699031: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-10 22:45:43.699388: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-10 22:45:43.709059: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-10 22:45:43.710237: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-10 22:45:43.719009: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 22:45:43.719131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:45:43.719764: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:45:43.720283: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-10 22:45:43.720643: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-08-10 22:45:43.725579: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-08-10 22:45:43.725853: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xf61a4c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-10 22:45:43.725887: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-10 22:45:43.821886: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:45:43.822740: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xf61a680 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-08-10 22:45:43.822774: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-08-10 22:45:43.822962: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:45:43.823552: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-08-10 22:45:43.823620: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 22:45:43.823638: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-10 22:45:43.823691: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-10 22:45:43.823706: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-10 22:45:43.823721: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-10 22:45:43.823735: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-10 22:45:43.823751: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 22:45:43.823828: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:45:43.824452: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:45:43.824997: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-10 22:45:43.825052: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 22:45:43.826142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-10 22:45:43.826168: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-08-10 22:45:43.826175: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-08-10 22:45:43.826295: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:45:43.826887: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:45:43.827453: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-08-10 22:45:43.827488: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# Running network: N/A% (0 of 419) |        | Elapsed Time: 0:00:00 ETA:  --:--:--WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2020-08-10 22:45:46.538613: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 22:45:47.573174: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# Running network: 100% (419 of 419) |######| Elapsed Time: 0:08:25 Time:  0:08:25
# Parsing annotations: 100% (419 of 419) |##| Elapsed Time: 0:00:00 Time:  0:00:00
# 663 instances of class defect with average precision: 0.3767
# Inference time for 419 images: 0.0618
# mAP using the weighted average of precisions among classes: 0.3767
# mAP: 0.3767

# %%
# Computation of mAP on validation subset
# !keras_retinanet/bin/evaluate.py --save-path output_map_val --iou-threshold 0.5 --score-threshold 0.05 csv {CSV_VALS} {INFERENCE_MODEL}
# Out:
# Using TensorFlow backend.
# Loading model, this may take a second...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_1:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_2:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_3:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_4:0' shape=(9, 4) dtype=float32> anchors
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From keras_retinanet/bin/../../keras_retinanet/backend/tensorflow_backend.py:104: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2020-08-10 22:55:55.668697: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-10 22:55:55.684900: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:55:55.685516: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-08-10 22:55:55.685778: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 22:55:55.687207: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-10 22:55:55.688391: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-10 22:55:55.688747: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-10 22:55:55.690383: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-10 22:55:55.691572: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-10 22:55:55.698511: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 22:55:55.698662: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:55:55.699311: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:55:55.699849: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-10 22:55:55.700194: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-08-10 22:55:55.704844: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-08-10 22:55:55.705095: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xe20c4c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-10 22:55:55.705125: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-10 22:55:55.796993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:55:55.797879: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xe20c680 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-08-10 22:55:55.797925: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-08-10 22:55:55.798106: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:55:55.798725: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-08-10 22:55:55.798793: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 22:55:55.798813: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-10 22:55:55.798830: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-10 22:55:55.798848: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-10 22:55:55.798864: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-10 22:55:55.798881: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-10 22:55:55.798898: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 22:55:55.798978: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:55:55.799629: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:55:55.800171: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-10 22:55:55.800261: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 22:55:55.801427: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-10 22:55:55.801456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-08-10 22:55:55.801464: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-08-10 22:55:55.801592: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:55:55.802196: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 22:55:55.802781: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-08-10 22:55:55.802816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# Running network: N/A% (0 of 1440) |       | Elapsed Time: 0:00:00 ETA:  --:--:--WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2020-08-10 22:55:58.596237: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 22:55:59.635340: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# Running network: 100% (1440 of 1440) |####| Elapsed Time: 0:30:42 Time:  0:30:42
# Parsing annotations: 100% (1440 of 1440) || Elapsed Time: 0:00:00 Time:  0:00:00
# 14400 instances of class defect with average precision: 0.9562
# Inference time for 1440 images: 0.0578
# mAP using the weighted average of precisions among classes: 0.9562
# mAP: 0.9562

# %% [markdown]
# # Detection of Bounding boxes in testing images

# %%
# show images inline
# %matplotlib inline

# automatically reload modules when they have changed
# %reload_ext autoreload
# %autoreload 2

# import keras
import keras

# import keras_retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color

# import miscellaneous modules
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time

# set tf backend to allow memory to grow, instead of claiming everything
import tensorflow as tf

def get_session():
    config = tf.ConfigProto()
    #config = tf.compat.v1.ConfigProto()
    config.gpu_options.allow_growth = True
    return tf.Session(config=config)

# use this environment flag to change which GPU to use
#os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# set the modified tf session as backend in keras
keras.backend.tensorflow_backend.set_session(get_session())

model_path = os.path.join('snapshots', sorted(os.listdir('snapshots'), reverse=True)[0])
print('model '+model_path+' loaded for inference.')

# load retinanet model
model = models.load_model(model_path, backbone_name='resnet50')
model = models.convert_model(model)

# load label to names mapping for visualization purposes
labels_to_names = pandas.read_csv(CLASSES,header=None).T.loc[0].to_dict()
# Out:
# Using TensorFlow backend.
# model snapshots/resnet50_csv_15.h5 loaded for inference.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /content/keras-retinanet/keras_retinanet/backend/tensorflow_backend.py:104: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_1:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_2:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_3:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_4:0' shape=(9, 4) dtype=float32> anchors

# %% [markdown]
# # Detection of Bounding boxes in testing images

# %%
def img_inference(img_path,img_infer,th_score=0.8,show=1):

  img_st = img_path+'/'+img_infer
  image = read_image_bgr(img_st)

  # copy to draw on
  draw = image.copy()
  draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

  # preprocess image for network
  image = preprocess_image(image)
  image, scale = resize_image(image)

  # process image
  start = time.time()
  boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
  print("processing time: ", time.time() - start)

  # correct for image scale
  boxes /= scale

  for box, score, label in zip(boxes[0], scores[0], labels[0]):
      # scores are sorted so we can break
      bt = box.astype(int)
      if score < th_score:
          break

      print(img_st+','+str(bt[0])+','+str(bt[3])+','+str(bt[3])+','+str(bt[3])+','+str(score)) 
      color = label_color(label)

      b = box.astype(int)
      draw_box(draw, b, color=color)

      caption = "{} {:.3f}".format(labels_to_names[label], score)
      draw_caption(draw, b, caption)

  plt.figure(figsize=(10, 10))
  plt.axis('off')
  plt.imshow(draw)
  plt.savefig('output/'+img_infer, dpi=300, bbox_inches='tight')
  if show:
    plt.show()
  else:
    plt.clf()

# %%
import os, fnmatch

def dirfiles(img_path,img_ext):
    img_names = fnmatch.filter(sorted(os.listdir(img_path)),img_ext)
    if '.DS_Store' in img_names:
        img_names.remove('.DS_Store')
    return img_names

def num2fixstr(x,d):
    st = '%0*d' % (d,x)
    return st

def detection_test_dir(img_path,fmt,th_score=0.8):
    st = '*.'+fmt
    img_names = dirfiles(img_path+'/',st)
    n = len(img_names)
    print('Detecting in ' + str(n) + ' images...')
    for i in range(n):
        img_infer = img_names[i]
        img_inference(img_path,img_infer,th_score,show=0)

def detection_test_full(img_path,fmt,th_score,show=0):

    st = '*.'+fmt
    img_names = dirfiles(img_path+'/',st)
    n = len(img_names)
    print('Detecting in ' + str(n) + ' images...')
    fd = open('bbox.csv','w') 
    stn = num2fixstr(n,4)
    for i in range(n):
        img_infer = img_names[i]
        image = read_image_bgr(img_path+'/'+img_infer)

        # copy to draw on
        draw = image.copy()
        draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

        # preprocess image for network
        image = preprocess_image(image)
        image, scale = resize_image(image)

        # process image
        start = time.time()
        boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
        img_st = img_path+'/'+img_infer
        print('['+num2fixstr(i,4)+'/'+stn+'] '+img_st+': processing time: ', time.time() - start)

        # correct for image scale
        boxes /= scale

        for box, score, label in zip(boxes[0], scores[0], labels[0]):
          # scores are sorted so we can break
          if score < th_score:
              break

          b = box.astype(int)
          fd.write(img_st+','+str(b[0])+','+str(b[1])+','+str(b[2])+','+str(b[3])+','+str(score)+'\n') 
          color = label_color(label)

          draw_box(draw, b, color=color)

          caption = "{} {:.3f}".format(labels_to_names[label], score)
          draw_caption(draw, b, caption)

        plt.figure(figsize=(10, 10))
        plt.axis('off')
        plt.imshow(draw)
        plt.savefig('output/'+img_infer, dpi=300, bbox_inches='tight')
        if show:
          plt.show()
        else:
          plt.clf()
    fd.close()

# %%
# !mkdir output

# %%
TH_DETECTION = 0.35
detection_test_full('cast/csv/images/test','jpg',th_score=TH_DETECTION)
# Out:
# Detecting in 720 images...
# [0000/0720] cast/csv/images/test/C0001_0001_01.jpg: processing time:  2.8721096515655518
# [0001/0720] cast/csv/images/test/C0001_0001_02.jpg: processing time:  0.05414247512817383
# [0002/0720] cast/csv/images/test/C0001_0001_03.jpg: processing time:  0.05298137664794922
# [0003/0720] cast/csv/images/test/C0001_0001_04.jpg: processing time:  0.05313611030578613
# [0004/0720] cast/csv/images/test/C0001_0001_05.jpg: processing time:  0.0561518669128418
# [0005/0720] cast/csv/images/test/C0001_0001_06.jpg: processing time:  0.05767703056335449
# [0006/0720] cast/csv/images/test/C0001_0001_07.jpg: processing time:  0.05621767044067383
# [0007/0720] cast/csv/images/test/C0001_0001_08.jpg: processing time:  0.05633854866027832
# [0008/0720] cast/csv/images/test/C0001_0001_09.jpg: processing time:  0.05701112747192383
# [0009/0720] cast/csv/images/test/C0001_0001_10.jpg: processing time:  0.056630611419677734
# [0010/0720] cast/csv/images/test/C0001_0002_01.jpg: processing time:  0.05656123161315918
# [0011/0720] cast/csv/images/test/C0001_0002_02.jpg: processing time:  0.056107282638549805
# [0012/0720] cast/csv/images/test/C0001_0002_03.jpg: processing time:  0.05517244338989258
# [0013/0720] cast/csv/images/test/C0001_0002_04.jpg: processing time:  0.056143760681152344
# [0014/0720] cast/csv/images/test/C0001_0002_05.jpg: processing time:  0.057962894439697266
# [0015/0720] cast/csv/images/test/C0001_0002_06.jpg: processing time:  0.056769609451293945
# [0016/0720] cast/csv/images/test/C0001_0002_07.jpg: processing time:  0.05716657638549805
# [0017/0720] cast/csv/images/test/C0001_0002_08.jpg: processing time:  0.056682586669921875
# [0018/0720] cast/csv/images/test/C0001_0002_09.jpg: processing time:  0.05636906623840332
# [0019/0720] cast/csv/images/test/C0001_0002_10.jpg: processing time:  0.05673956871032715
# [0020/0720] cast/csv/images/test/C0001_0003_01.jpg: processing time:  0.056887149810791016
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py